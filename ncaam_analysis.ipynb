# %%
# from bs4 import BeautifulSoup
# import pandas as pd
# import requests
# import json

# import matplotlib.pyplot as plt
# import seaborn as sns
# from matplotlib.patches import Circle, Rectangle, Arc

from get_game_shots import get_game_shots
from draw_court import draw_court
from draw_shot_chart import draw_shot_chart

# %%
get_game_shots(401490418)
# Out:
#                      ID  Half  \
# 0    401490418101806401     1
# 1    401490418101807201     1
# 2    401490418101809601     1
# 3    401490418101814602     1
# 4    401490418101814603     1
# ..                  ...   ...
# 157  401490418102997301     2
# 158  401490418102998101     2
# 159  401490418102998602     2
# 160  401490418102998604     2
# 161  401490418102998701     2
#
#                                          Description Home/Away Athlete ID  \
# 0                         Oumar Ballo missed Jumper.      away    4594109
# 1        Jaime Jaquez Jr. missed Three Point Jumper.      home    4432848
# 2                     Azuolas Tubelis missed Jumper.      away    4702372
# 3                   Azuolas Tubelis made Free Throw.      away    4702372
# 4                   Azuolas Tubelis made Free Throw.      away    4702372
# ..                                               ...       ...        ...
# 157                       Kylan Boswell made Jumper.      away    4684269
# ...

# %%
draw_court()
# Out:
# <Axes: >

# %%
draw_shot_chart(401490418)

# %%
soup = BeautifulSoup(r.content)
print(soup.prettify())

table = soup.find('div', attrs = {'class':'ShotChart__court__wrap'})

for row in table.findAll('li', attrs = {'class':'ShotChart__court__play'}):
    print(row)
